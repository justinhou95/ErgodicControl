# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(0)

# %% [markdown]
# Consider control of Brownian motion
# $$
# dX_{t} = dW_{t} + u_{t}dt
# $$
#
# Ergodic control
# $$
# \min_{u}\liminf_{T\to\infty}\frac{1}{T}E\big[\int_{0}^{T}c(X_t,u_t)dt\big]
# $$
#
# where
# $$
# c(X_{t},u_{t}) = X_{t}^{2} + u_{t}^{2}
# $$
#
# Naive approach, considering the truncated problem
# $$
# u^{*} = \arg\min E\big[\int_{t_{n}}^{t_{n+1}}c(X_{t},u_{t})dt\big]
# $$

# %%
# Control Neural Network

inputs = keras.Input(shape=(1))
l1 = layers.Dense(8, activation = 'relu')
l2= layers.Dense(1, activation = 'linear')
outputs = l1(inputs)
outputs = l2(outputs)
# outputs = -inputs
control_NN = keras.Model(inputs=inputs, outputs=outputs, name = 'control_NN')
control_NN.summary()
control_NN.compile(loss = 'mse')
xgrid = np.linspace(-10,10,201)
y = control_NN.predict(xgrid)
plt.plot(xgrid,y)
plt.grid()
# Out:
# Model: "control_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 16
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Global Parameter
steps = 100
dt = 0.1
sqrtdt = np.sqrt(dt)
T = steps * dt
M = 1000

# %%
input_x = keras.Input(shape=(1))
inputs = [input_x]

X_now = input_x
u_now = control_NN(X_now)
loss = tf.math.square(X_now) + tf.math.square(u_now)
loss_output = [loss]

for i in range(steps):
    input_dW = keras.Input(shape=(1))
    inputs = inputs + [input_dW]
    u_now = control_NN(X_now)
    X_next  = X_now + input_dW + u_now * dt
    loss_tmp = tf.math.square(X_now) + tf.math.square(u_now)
    loss_output = loss_output + [loss_tmp]
    loss = loss + loss_tmp
    X_now = X_next

control_main = keras.Model(inputs=inputs, outputs = loss / (steps+1), name = 'control_main')
control_terminal = keras.Model(inputs=inputs, outputs = X_now, name = 'control_terminal')
control_loss = keras.Model(inputs=inputs, outputs = loss_output, name = 'control_loss')
# control_loss.summary()

control_main.compile(loss = 'mean_absolute_error')
control_terminal.compile(loss = 'mean_absolute_error')
control_loss.compile(loss = 'mean_absolute_error')

# %%
def trainning_data(seed,X0,samplesM):
    np.random.seed(seed)
    x = [X0]
    for i in range(steps):
        x = x + [np.random.normal(0,sqrtdt,size = (samplesM,1))]
    y = np.zeros(shape = (samplesM,1))
    return x, y

# %%
# X0 = np.random.normal(0,np.sqrt(1/2),size = (M,1))
X0 = np.ones(shape = (M,1))
x_train, y_train = trainning_data(0,X0,M)
x_valid, y_valid = trainning_data(1,X0,M)
x_test, y_test = trainning_data(2,X0,M)

# %%
# Optimal control
X = x_train[0][:,0]
rho = np.zeros(steps+1)
rho[0] = np.mean(2*X**2)
for it in range(steps):
    dW = x_train[it+1][:,0]
    X  = X + dW + -X*dt
    rho[it+1] = np.mean(2*X**2)
    
plt.rcParams['figure.figsize'] = (12.0, 4.0)
dates = np.linspace(0,steps*dt,steps+1)
plt.plot(dates,rho)
plt.grid()
print('mean cost: ', rho.mean())
print('terminal mean: ', X.mean())
print('terminal variance: ', X.var())
# Out:
# mean cost:  1.070332368398875
# terminal mean:  0.05852963082889483
# terminal variance:  0.5380155384384356

# %%
control_main.evaluate(x_train,y_train)
control_main.fit(x_train,y_train,epochs = 20,validation_data = (x_valid,y_valid), verbose = 1)
# Out:
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 21133.8247
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/20
# 1000/1000 [==============================] - 12s 12ms/sample - loss: 7182.3961 - val_loss: 2807.3626
# Epoch 2/20
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 1499.1415 - val_loss: 854.3163
# Epoch 3/20
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 455.0296 - val_loss: 265.2570
# Epoch 4/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 150.2764 - val_loss: 94.6864
# Epoch 5/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 52.6966 - val_loss: 33.8066
# Epoch 6/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 19.4113 - val_loss: 13.2699
# Epoch 7/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 8.1237 - val_loss: 6.0751
# Epoch 8/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 4.1916 - val_loss: 3.4116
# Epoch 9/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.5979 - val_loss: 2.2802
# Epoch 10/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.8965 - val_loss: 1.7520
# Epoch 11/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.5438 - val_loss: 1.4650
# Epoch 12/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.3407 - val_loss: 1.3022
# Epoch 13/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.2198 - val_loss: 1.2069
# Epoch 14/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.1494 - val_loss: 1.1494
# Epoch 15/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.1113 - val_loss: 1.1252
# Epoch 16/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0957 - val_loss: 1.1152
# Epoch 17/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0898 - val_loss: 1.1120
# Epoch 18/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0873 - val_loss: 1.1096
# Epoch 19/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0856 - val_loss: 1.1085
# Epoch 20/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0843 - val_loss: 1.1074

# %%
all_loss = control_loss.predict(x_test)
plt_loss = np.zeros(steps+1)
for i,x in enumerate(all_loss):
    plt_loss[i] = x.mean()
plt.plot(dates,plt_loss)
plt.grid()
X_end = control_terminal.predict(x_test)

print('mean cost: ', plt_loss.mean())
print('terminal mean after 1 iteration: ', X_end.mean())
print('terminal variance after 1 iteration: ', X_end.var())
# Out:
# mean cost:  1.125616149146958
# terminal mean after 1 iteration:  -0.012980917
# terminal variance after 1 iteration:  0.59883153

# %%
all_loss = control_loss.predict(x_train)
plt_loss = np.zeros(steps+1)
for i,x in enumerate(all_loss):
    plt_loss[i] = x.mean()
plt.plot(dates,plt_loss)
plt.grid()
X_end = control_terminal.predict(x_train)
print('mean cost: ', plt_loss.mean())
print('terminal mean after 1 iteration: ', X_end.mean())
print('terminal variance after 1 iteration: ', X_end.var())

for i in range(3):
    newX0 = np.random.normal(X_end.mean(),X_end.std(),size = (M,1))
    x_t, y_t = trainning_data(i+5,newX0,M)
    x_v, y_v = trainning_data(i+500,newX0,M)
    control_main.fit(x_t,y_t,epochs = 1,validation_data = (x_v,y_v), verbose = 1)
    
    all_loss = control_loss.predict(x_t)
    plt_loss = np.zeros(steps+1)
    for j,x in enumerate(all_loss):
        plt_loss[j] = x.mean()
    plt.plot(dates+10*(i+1),plt_loss)
    X_end = control_terminal.predict(x_t)
    print(f'mean cost after {i+2} iteration', plt_loss.mean())
    print(f'terminal mean after {i+2} iteration: ',  X_end.mean())
    print(f'terminal variance after {i+2} iteration: ',  X_end.var())
# Out:
# mean cost:  1.083372958225779
# terminal mean after 1 iteration:  0.053270426
# terminal variance after 1 iteration:  0.61956227
# Train on 1000 samples, validate on 1000 samples
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0807 - val_loss: 1.0619
# mean cost after 2 iteration 1.0793933089416805
# terminal mean after 2 iteration:  -0.050251786
# terminal variance after 2 iteration:  0.56094974
# Train on 1000 samples, validate on 1000 samples
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0527 - val_loss: 1.0520
# mean cost after 3 iteration 1.0517541937308736
# terminal mean after 3 iteration:  0.02371099
# terminal variance after 3 iteration:  0.60694677
# Train on 1000 samples, validate on 1000 samples
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0757 - val_loss: 1.0672: 0s - loss: 1.07
# mean cost after 4 iteration 1.0749230957267308
# terminal mean after 4 iteration:  -0.0094688665
# terminal variance after 4 iteration:  0.585129

# %%
control_NN.compile(loss = 'mse')
xgrid = np.linspace(-10,10,201)
y = control_NN.predict(xgrid)
plt.plot(xgrid,y)
plt.grid()
