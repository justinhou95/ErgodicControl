# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
tf.random.set_seed(0)

# %% [markdown]
# Consider control of Brownian motion
# $$
# dX_{t} = dW_{t} + u_{t}dt
# $$
#
# Ergodic control
# $$
# \min_{u}\liminf_{T\to\infty}\frac{1}{T}E\big[\int_{0}^{T}c(X_t,u_t)dt\big]
# $$
#
# where
# $$
# c(X_{t},u_{t}) = X_{t}^{2} + u_{t}^{2}
# $$
#
# Naive approach, considering the truncated problem
# $$
# u^{*} = \arg\min E\big[\int_{t_{n}}^{t_{n+1}}c(X_{t},u_{t})dt\big]
# $$

# %%
# Control Neural Network

inputs = keras.Input(shape=(1))
l1 = layers.Dense(8, activation = 'relu')
l2= layers.Dense(1, activation = 'linear')
outputs = l1(inputs)
outputs = l2(outputs)
# outputs = -inputs
control_NN = keras.Model(inputs=inputs, outputs=outputs, name = 'control_NN')
control_NN.summary()
control_NN.compile(loss = 'mse')
xgrid = np.linspace(-10,10,201)
y = control_NN.predict(xgrid)
plt.plot(xgrid,y)
plt.grid()
# Out:
# Model: "control_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1)]               0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 16
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Global Parameter
steps = 100
dt = 0.1
sqrtdt = np.sqrt(dt)
T = steps * dt
M = 1000

# %%
input_x = keras.Input(shape=(1))
inputs = [input_x]

X_now = input_x
u_now = control_NN(X_now)
loss = tf.math.square(X_now) + tf.math.square(u_now)
loss_output = [loss]

for i in range(steps):
    input_dW = keras.Input(shape=(1))
    inputs = inputs + [input_dW]
    u_now = control_NN(X_now)
    X_next  = X_now + input_dW + u_now * dt
    loss_tmp = tf.math.square(X_now) + tf.math.square(u_now)
    loss_output = loss_output + [loss_tmp]
    loss = loss + loss_tmp
    X_now = X_next

control_main = keras.Model(inputs=inputs, outputs = loss / (steps+1), name = 'control_main')
control_terminal = keras.Model(inputs=inputs, outputs = X_now, name = 'control_terminal')
control_loss = keras.Model(inputs=inputs, outputs = loss_output, name = 'control_loss')
# control_loss.summary()

control_main.compile(loss = 'mean_absolute_error')
control_terminal.compile(loss = 'mean_absolute_error')
control_loss.compile(loss = 'mean_absolute_error')

# %%
def trainning_data(seed,X0,samplesM):
    np.random.seed(seed)
    x = [X0]
    for i in range(steps):
        x = x + [np.random.normal(0,sqrtdt,size = (samplesM,1))]
    y = np.zeros(shape = (samplesM,1))
    return x, y

# %%
# Global Parameter
steps = 1000
dt = 0.01
sqrtdt = np.sqrt(dt)
T = steps * dt
M = 10000
X0 = np.random.normal(0,np.sqrt(1/2),size = (M,1))
x_train, y_train = trainning_data(0,X0,M)
x_valid, y_valid = trainning_data(1,X0,M)
x_test, y_test = trainning_data(2,X0,M)

# %%
# Optimal control
X = x_train[0][:,0]
rho = np.zeros(steps+1)
rho[0] = np.mean(2*X**2)
for it in range(steps):
    dW = x_train[it+1][:,0]
    X  = X + dW + -X*dt
    rho[it+1] = np.mean(2*X**2)
    
plt.rcParams['figure.figsize'] = (12.0, 4.0)
dates = np.linspace(0,steps*dt,steps+1)
plt.plot(dates,rho)
plt.grid()
print('mean cost: ', rho.mean())
print('terminal mean: ', X.mean())
print('terminal variance: ', X.var())
# Out:
# mean cost:  1.0006136730829491
# terminal mean:  -0.0021001706076724616
# terminal variance:  0.4968753154851083

# %%
control_main.evaluate(x_train,y_train)
control_main.fit(x_train,y_train,epochs = 20,validation_data = (x_valid,y_valid), verbose = 1)
# Out:
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 10978.3157
# Train on 1000 samples, validate on 1000 samples
# Epoch 1/20
# 1000/1000 [==============================] - 12s 12ms/sample - loss: 3981.0651 - val_loss: 1809.7991
# Epoch 2/20
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 891.2862 - val_loss: 568.3473
# Epoch 3/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 270.7009 - val_loss: 180.1202
# Epoch 4/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 93.6268 - val_loss: 67.0858
# Epoch 5/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 35.1807 - val_loss: 25.9899
# Epoch 6/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 14.3404 - val_loss: 11.4221
# Epoch 7/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 6.8387 - val_loss: 5.6607
# Epoch 8/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 3.8657 - val_loss: 3.3948
# Epoch 9/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 2.5724 - val_loss: 2.3394
# Epoch 10/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.9318 - val_loss: 1.8157
# Epoch 11/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.5744 - val_loss: 1.4929
# Epoch 12/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.3560 - val_loss: 1.3183
# Epoch 13/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.2275 - val_loss: 1.2132
# Epoch 14/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.1519 - val_loss: 1.1500
# Epoch 15/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.1117 - val_loss: 1.1233
# Epoch 16/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0955 - val_loss: 1.1119
# Epoch 17/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0899 - val_loss: 1.1087
# Epoch 18/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0876 - val_loss: 1.1061
# Epoch 19/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0860 - val_loss: 1.1048
# Epoch 20/20
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0848 - val_loss: 1.1036

# %%
all_loss = control_loss.predict(x_test)
plt_loss = np.zeros(steps+1)
for i,x in enumerate(all_loss):
    plt_loss[i] = x.mean()
plt.plot(dates,plt_loss)
plt.grid()
X_end = control_terminal.predict(x_test)

print('mean cost: ', plt_loss.mean())
print('terminal mean after 1 iteration: ', X_end.mean())
print('terminal variance after 1 iteration: ', X_end.var())
# Out:
# mean cost:  0.016211987516799056
# terminal mean after 1 iteration:  0.020961383
# terminal variance after 1 iteration:  0.060077187

# %%
all_loss = control_loss.predict(x_train)
plt_loss = np.zeros(steps+1)
for i,x in enumerate(all_loss):
    plt_loss[i] = x.mean()
plt.plot(dates,plt_loss)
plt.grid()
X_end = control_terminal.predict(x_train)
print('mean cost: ', plt_loss.mean())
print('terminal mean after 1 iteration: ', X_end.mean())
print('terminal variance after 1 iteration: ', X_end.var())

for i in range(3):
    newX0 = np.random.normal(X_end.mean(),X_end.std(),size = (M,1))
    x_t, y_t = trainning_data(i+5,newX0,M)
    x_v, y_v = trainning_data(i+500,newX0,M)
    control_main.fit(x_t,y_t,epochs = 1,validation_data = (x_v,y_v), verbose = 1)
    
    all_loss = control_loss.predict(x_t)
    plt_loss = np.zeros(steps+1)
    for j,x in enumerate(all_loss):
        plt_loss[j] = x.mean()
    plt.plot(dates+10*(i+1),plt_loss)
    X_end = control_terminal.predict(x_t)
    print(f'mean cost after {i+2} iteration', plt_loss.mean())
    print(f'terminal mean after {i+2} iteration: ',  X_end.mean())
    print(f'terminal variance after {i+2} iteration: ',  X_end.var())
# Out:
# mean cost:  1.0714422476173628
# terminal mean after 1 iteration:  0.0441123
# terminal variance after 1 iteration:  0.59277123
# Train on 1000 samples, validate on 1000 samples
# 1000/1000 [==============================] - 2s 2ms/sample - loss: 1.0639 - val_loss: 1.0450
# mean cost after 2 iteration 1.063679010561197
# terminal mean after 2 iteration:  -0.04608049
# terminal variance after 2 iteration:  0.55464953
# Train on 1000 samples, validate on 1000 samples
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0423 - val_loss: 1.0407
# mean cost after 3 iteration 1.0417864493804403
# terminal mean after 3 iteration:  0.023711758
# terminal variance after 3 iteration:  0.59435904
# Train on 1000 samples, validate on 1000 samples
# 1000/1000 [==============================] - 1s 1ms/sample - loss: 1.0640 - val_loss: 1.0573
# mean cost after 4 iteration 1.0638628820381542
# terminal mean after 4 iteration:  -0.00067154743
# terminal variance after 4 iteration:  0.58351356

# %%
control_NN.compile(loss = 'mse')
xgrid = np.linspace(-10,10,201)
y = control_NN.predict(xgrid)
plt.plot(xgrid,y)
plt.grid()

# %%
# Stimulation of the optimal case
T = 2
N = 20
M = 1000
dt = T/N
dates = np.linspace(0,T,N+1)
sqrtdt = np.sqrt(dt)
X0 = np.random.normal(0,np.sqrt(1),size = (M))
X = np.zeros(shape = (N+1,M))
rho = np.zeros(N+1)
X[0,:] = X0
rho[0] = c_cost(X0)
for it in range(N):
    dW = np.random.normal(0,sqrtdt,size = (M))
    X[it+1,:]  = X[it,:] + dW + u_control(X[it,:])*dt
    rho[it+1] = c_cost(X[it+1,:]) 
plt.rcParams['figure.figsize'] = (12.0, 4.0)
plt.plot(dates,rho)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d9d8ce81aefe> in <module>
#      10 rho = np.zeros(N+1)
#      11 X[0,:] = X0
# ---> 12 rho[0] = c_cost(X0)
#      13 for it in range(N):
#      14     dW = np.random.normal(0,sqrtdt,size = (M))
#
# NameError: name 'c_cost' is not defined
